# %% [markdown]
# <a href="https://colab.research.google.com/github/atortosalopez/trabajo-final-sentimientos/blob/main/notebooks/01_lexicon_vader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment pandas scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38c1e006-59e3-4db8-9003-872d7171097b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38c1e006-59e3-4db8-9003-872d7171097b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

test_df = pd.read_csv("test.csv")

print(test_df.head())
# Out:
#                                                 text  label
# 0  did the film inform and educate me ? yes . did...      0
# 1  an unsophisticated sci-fi drama that takes its...      0
# 2  it seems like i have been waiting my whole lif...      1
# 3   the stories here suffer from the chosen format .      0
# 4  it's dark but has wonderfully funny moments ; ...      1

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def vader_predict(text):
    score = analyzer.polarity_scores(text)["compound"]

    if score >= 0:
        return 1  # positivo
    else:
        return 0  # negativo

test_df["pred_lexicon"] = test_df["text"].apply(vader_predict)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

y_true = test_df["label"]
y_pred = test_df["pred_lexicon"]

print("Accuracy:", accuracy_score(y_true, y_pred))
print("Precision:", precision_score(y_true, y_pred))
print("Recall:", recall_score(y_true, y_pred))
print("F1:", f1_score(y_true, y_pred))

print("\nClassification report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Accuracy: 0.61875
# Precision: 0.5817555938037866
# Recall: 0.845
# F1: 0.6890927624872579
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.39      0.51       800
#            1       0.58      0.84      0.69       800
#
#     accuracy                           0.62      1600
#    macro avg       0.65      0.62      0.60      1600
# weighted avg       0.65      0.62      0.60      1600

# %%
errors = test_df[test_df["label"] != test_df["pred_lexicon"]]

print(errors[["text", "label", "pred_lexicon"]].head(10))
# Out:
#                                                  text  label  pred_lexicon
# 0   did the film inform and educate me ? yes . did...      0             1
# 6   not that any of us should be complaining when ...      0             1
# 16  this remake gets all there is to get out of a ...      1             0
# 18  the bottom line , at least in my opinion , is ...      0             1
# 19  a collage of clichés and a dim echo of allusio...      0             1
# 20  when a set of pre-shooting guidelines a direct...      0             1
# 23  it is far from the worst , thanks to the topic...      1             0
# 24  returning aggressively to his formula of dimwi...      0             1
# 25  it pulls the rug out from under you , just whe...      1             0
# 27  while the resident evil games may have set new...      0             1

# %%
test_df.to_csv("corpus_pred_lexicon.csv", index=False)
